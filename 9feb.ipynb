# %%
#1
def pi(s):
    if len(str) < 2:
        return" "
    if s[0] == 'p ' and s[1]== 'i':
        return "3.14"+ pi(s[2:])
    else:
        return s[0]+ pi(s[1:])

str = input("enter string =")
print ("updated" ,pi(str))
# Out:
# enter string = pis
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 11
#       8         return s[0]+ pi(s[1:])
#      10 str = input("enter string =")
# ---> 11 print ("updated" ,pi(str))
#
# Cell In[5], line 8, in pi(s)
#       6     return "3.14"+ pi(s[2:])
#       7 else:
# ----> 8     return s[0]+ pi(s[1:])
#
# Cell In[5], line 8, in pi(s)
#       6     return "3.14"+ pi(s[2:])
#       7 else:
# ----> 8     return s[0]+ pi(s[1:])
#
# Cell In[5], line 8, in pi(s)
#       6     return "3.14"+ pi(s[2:])
#       7 else:
# ----> 8     return s[0]+ pi(s[1:])
#
# Cell In[5], line 5, in pi(s)
#       3 if len(str) < 2:
#       4     return" "
# ----> 5 if s[0] == 'p ' and s[1]== 'i':
#       6     return "3.14"+ pi(s[2:])
#       7 else:
#
# IndexError: string index out of range
