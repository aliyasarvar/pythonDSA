# %%
#1
def count(s, ch):
    if len(s) == 0:
        return 0
    if s[0] == ch:
        return 1 + count(s[1:], ch)
    else:
        return count(s[1:], ch)


string = input("Enter string: ")
char = input("Enter character to count: ")

result = count(string, char)
print("Total :", result)
# Out:
# Enter string:  blacks
# Enter character to count:  s
# Total : 1

# %%
#2
def first(s, ch, i=0):
    if i == len(s):
        return -1
    if s[i] == ch:
        return i
    return first(s, ch, i + 1)


string = input("Enter string: ")
char = input("Enter character to find index: ")

result = first(string, char)
print("First index:", result)
# Out:
# Enter string:  bananas
# Enter character to find index:  a
# First index: 1

# %%
#3
def remove(s):
    if len(s) <= 1:
        return s
    
    small_output = remove(s[1:])
    
    if s[0] in small_output:
        return small_output
    else:
        return s[0] + small_output


string = input("Enter string: ")

result = remove(string)
print("String after removing duplicates:", result)
# Out:
# Enter string:  banana
# String after removing duplicates: bna

# %%
#4
def replace(s, old, new):
    if len(s) == 0:
        return ""
    if s[0] == old:
        return new + replace(s[1:], old, new)
    else:
        return s[0] + replace(s[1:], old, new)


string = input("Enter string: ")
old_char = input("Enter character to replace: ")
new_char = input("Enter new character: ")

result = replace(string, old_char, new_char)
print("Updated string:", result)
# Out:
# Enter string:  banana
# Enter character to replace:  a
# Enter new character:  b
# Updated string: bbnbnb

# %%
#5
def removex(s):
    if len(s) == 0:
        return ""
    if s[0] == 'x':
        return removex(s[1:])
    else:
        return s[0] + removex(s[1:])


string = input("Enter string: ")

result = removex(string)
print("String after removing 'x':", result)
# Out:
# Enter string:  xalxo
# String after removing 'x': alo
